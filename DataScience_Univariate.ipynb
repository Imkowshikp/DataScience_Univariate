# %% [markdown]
# # Kowshik P
# ## Assignment submitted on 14-May-2022
#
# ## Concepts :
# ## 1. Measure of Location of the data
# ## 2. Measure of the central Tendency

# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as mat;

# %%
rawData = pd.read_csv("Placement.csv");

rawData
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
rawData.iloc[:, [13]]
# Out:
#          status
# 0        Placed
# 1        Placed
# 2        Placed
# 3    Not Placed
# 4        Placed
# ..          ...
# 210      Placed
# 211      Placed
# 212      Placed
# 213      Placed
# 214  Not Placed
#
# [215 rows x 1 columns]

# %%
rawData.iat[3, 13]
# Out:
# 'Not Placed'

# %%
rawData["status"].values
# Out:
# array(['Placed', 'Placed', 'Placed', 'Not Placed', 'Placed', 'Not Placed',
#        'Not Placed', 'Placed', 'Placed', 'Not Placed', 'Placed', 'Placed',
#        'Not Placed', 'Placed', 'Not Placed', 'Placed', 'Placed',
#        'Not Placed', 'Not Placed', 'Placed', 'Placed', 'Placed', 'Placed',
#        'Placed', 'Placed', 'Not Placed', 'Placed', 'Placed', 'Placed',
#        'Not Placed', 'Placed', 'Not Placed', 'Placed', 'Placed',
#        'Not Placed', 'Placed', 'Not Placed', 'Placed', 'Placed', 'Placed',
#        'Placed', 'Not Placed', 'Not Placed', 'Placed', 'Placed',
#        'Not Placed', 'Not Placed', 'Placed', 'Placed', 'Not Placed',
#        'Placed', 'Not Placed', 'Not Placed', 'Placed', 'Placed', 'Placed',
#        'Placed', 'Placed', 'Placed', 'Placed', 'Placed', 'Placed',
#        'Placed', 'Not Placed', 'Placed', 'Not Placed', 'Placed', 'Placed',
#        'Not Placed', 'Placed', 'Placed', 'Placed', 'Placed', 'Placed',
# ...

# %%
rawData.filter(like = "status")
# Out:
#          status
# 0        Placed
# 1        Placed
# 2        Placed
# 3    Not Placed
# 4        Placed
# ..          ...
# 210      Placed
# 211      Placed
# 212      Placed
# 213      Placed
# 214  Not Placed
#
# [215 rows x 1 columns]

# %%
rawData.query("status == 'Not Placed'")
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central  52.00  Central   Science     52.00
# 5        6      M   55.0   Others  49.80   Others   Science     67.25
# 6        7      F   46.0   Others  49.20   Others  Commerce     79.00
# 9       10      M   58.0  Central  70.00  Central  Commerce     61.00
# 12      13      F   47.0  Central  55.00   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central  70.00  Central  Commerce     65.00
# 201    202      M   54.2  Central  63.00   Others   Science     58.00
# 206    207      M   41.0  Central  42.75  Central   Science     60.00
# 208    209      F   43.0  Central  60.00   Others   Science     65.00
# 214    215      M   62.0  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %% [markdown]
# ## Finding "Null" or "Nan" values

# %%
rawData.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# ## Fixed the Null values using "fillna()" function

# %%
rawData["salary"] = rawData["salary"].fillna(0);

# %% [markdown]
# ## Updated Dataset-(Salary column)

# %%
rawDataUpdate = rawData;

rawDataUpdate
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
rawDataUpdate.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
rawDataUpdate.info()

# %%
rawDataUpdate["ssc_p"].dtypes

# %%
rawDataUpdate["gender"].dtypes

# %%
rawDataUpdate["sl_no"].dtypes

# %% [markdown]
# ## Dropped "sl.no" column

# %%
columnNames = rawDataUpdate.columns;

columnNamesUpdate = columnNames.drop(["sl_no"])

columnNamesUpdate
# Out:
# Index(['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',
#        'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status',
#        'salary'],
#       dtype='object')

# %%
quantitative = [];
qualitative = [];

# %% [markdown]
# ## Function created for respective columns

# %%
def setquantitativeQualitative(rawDataUpdate, quantitative, qualitative):
    
    columnNamesUpdate;
    
    quantitative = [];
    qualitative = [];

    for columnSet in columnNamesUpdate:
        if(rawDataUpdate[columnSet].dtypes == "O"):
            qualitative.append(columnSet)
        else:
            quantitative.append(columnSet)
            
    return quantitative, qualitative

setquantitativeQualitative(rawDataUpdate, quantitative, qualitative)
# Out:
# (['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %% [markdown]
# ## Quantitative and Qualitative columns are segregated

# %%
quantitative, qualitative = setquantitativeQualitative(rawDataUpdate, quantitative, qualitative)

# %%
print(quantitative);
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %% [markdown]
# ## Finding Meaning, Median and Mode for respective columns

# %%
rawDataUpdate["ssc_p"].mean()

# %%
rawDataUpdate["hsc_p"].mean()

# %%
rawDataUpdate["ssc_p"].median()

# %%
rawDataUpdate["hsc_p"].median()

# %%
rawDataUpdate["ssc_p"].mode()[0]

# %%
rawDataUpdate["hsc_p"].mode()[0]

# %%
rawDataUpdate[columnNamesUpdate].mean()

# %%
rawDataUpdate[columnNamesUpdate].median()

# %%
rawDataUpdate[columnNamesUpdate].mode()

# %% [markdown]
# ## Finding Percentile for respective columns

# %%
np.percentile(rawDataUpdate["ssc_p"], 25)

# %%
np.percentile(rawDataUpdate["ssc_p"], 50)

# %%
np.percentile(rawDataUpdate["ssc_p"], 75)

# %%
np.percentile(rawDataUpdate["ssc_p"], 99)

# %%
np.percentile(rawDataUpdate["ssc_p"], 100)

# %%
np.percentile(rawDataUpdate["hsc_p"], 25)

# %%
np.percentile(rawDataUpdate["hsc_p"], 50)

# %% [markdown]
# ## Created table for central Tendency

# %%
#meanMedianModeTable["ssc_p"]["Mean"] = 0

#meanMedianModeTable

# %%
def centralTendency(rawDataUpdate, quantitative):
    
    meanMedianModeTable = pd.DataFrame(index = ["Mean", "Median", "Mode", "Percentile(Q1)-25th", 
                                                "Percentile-35th", "Percentile(Q2)-50th", "Percentile-60th", 
                                                "Percentile(Q3)-75th", "Percentile-80th", "Percentile-99th", 
                                                "Percentile(Q4)-100th", "IQR", "1.5*IQR", 
                                                "Lesser_Outlier", "Greater_Outlier", "Minimum_Value",
                                                "Maximum_Value"], columns = quantitative)

    for setQuantitativeValue in quantitative:

        meanMedianModeTable[setQuantitativeValue]["Mean"] = rawDataUpdate[setQuantitativeValue].mean()
        meanMedianModeTable[setQuantitativeValue]["Median"] = rawDataUpdate[setQuantitativeValue].median()
        meanMedianModeTable[setQuantitativeValue]["Mode"] = rawDataUpdate[setQuantitativeValue].mode()[0]
        meanMedianModeTable[setQuantitativeValue]["Percentile(Q1)-25th"] = np.percentile(rawDataUpdate[setQuantitativeValue], 25)
        meanMedianModeTable[setQuantitativeValue]["Percentile-35th"] = np.percentile(rawDataUpdate[setQuantitativeValue], 35)
        meanMedianModeTable[setQuantitativeValue]["Percentile(Q2)-50th"] = np.percentile(rawDataUpdate[setQuantitativeValue], 50)
        meanMedianModeTable[setQuantitativeValue]["Percentile-60th"] = np.percentile(rawDataUpdate[setQuantitativeValue], 60)
        meanMedianModeTable[setQuantitativeValue]["Percentile(Q3)-75th"] = np.percentile(rawDataUpdate[setQuantitativeValue], 75)
        meanMedianModeTable[setQuantitativeValue]["Percentile-80th"] = np.percentile(rawDataUpdate[setQuantitativeValue], 80)
        meanMedianModeTable[setQuantitativeValue]["Percentile-99th"] = np.percentile(rawDataUpdate[setQuantitativeValue], 99)
        meanMedianModeTable[setQuantitativeValue]["Percentile(Q4)-100th"] = np.percentile(rawDataUpdate[setQuantitativeValue], 100)

        q1 = meanMedianModeTable[setQuantitativeValue]["Percentile(Q1)-25th"];
        q2 = meanMedianModeTable[setQuantitativeValue]["Percentile(Q2)-50th"];
        q3 = meanMedianModeTable[setQuantitativeValue]["Percentile(Q3)-75th"];
        q4 = meanMedianModeTable[setQuantitativeValue]["Percentile(Q4)-100th"];

        meanMedianModeTable[setQuantitativeValue]["IQR"] = q3 - q1;

        IQR = meanMedianModeTable[setQuantitativeValue]["IQR"];

        value_IQR = 1.5*IQR;

        meanMedianModeTable[setQuantitativeValue]["1.5*IQR"] = value_IQR;

        lesserOutlier = q1 - value_IQR;
        greaterOutlier = q3 + value_IQR;

        meanMedianModeTable[setQuantitativeValue]["Lesser_Outlier"] = lesserOutlier;
        meanMedianModeTable[setQuantitativeValue]["Greater_Outlier"] = greaterOutlier;
        meanMedianModeTable[setQuantitativeValue]["Minimum_Value"] = rawDataUpdate[setQuantitativeValue].min()
        meanMedianModeTable[setQuantitativeValue]["Maximum_Value"] = rawDataUpdate[setQuantitativeValue].max()
        
    return meanMedianModeTable

centralTendency(rawDataUpdate, quantitative)
# Out:
#                           ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean                  67.303395  66.333163  66.370186  72.100558  62.278186
# Median                     67.0       65.0       66.0       71.0       62.0
# Mode                       62.0       63.0       65.0       60.0       56.7
# Percentile(Q1)-25th        60.6       60.9       61.0       60.0     57.945
# Percentile-35th            63.0      62.45      64.18       64.0     59.466
# Percentile(Q2)-50th        67.0       65.0       66.0       71.0       62.0
# Percentile-60th            70.0      67.52      67.44       75.0      63.02
# Percentile(Q3)-75th        75.7       73.0       72.0       83.5     66.255
# Percentile-80th            77.0     74.728     72.134       86.0     67.144
# Percentile-99th            87.0      91.86      83.86       97.0    76.1142
# Percentile(Q4)-100th       89.4       97.7       91.0       98.0      77.89
# ...

# %% [markdown]
# ## Central Tendency function stored in variable

# %%
centralTendencyTable = centralTendency(rawDataUpdate, quantitative);

centralTendencyTable
# Out:
#                           ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean                  67.303395  66.333163  66.370186  72.100558  62.278186
# Median                     67.0       65.0       66.0       71.0       62.0
# Mode                       62.0       63.0       65.0       60.0       56.7
# Percentile(Q1)-25th        60.6       60.9       61.0       60.0     57.945
# Percentile-35th            63.0      62.45      64.18       64.0     59.466
# Percentile(Q2)-50th        67.0       65.0       66.0       71.0       62.0
# Percentile-60th            70.0      67.52      67.44       75.0      63.02
# Percentile(Q3)-75th        75.7       73.0       72.0       83.5     66.255
# Percentile-80th            77.0     74.728     72.134       86.0     67.144
# Percentile-99th            87.0      91.86      83.86       97.0    76.1142
# Percentile(Q4)-100th       89.4       97.7       91.0       98.0      77.89
# ...

# %% [markdown]
# ## Finding Frequency for the respective column
# ## Index sorted in ascending order

# %%
rawDataUpdate["ssc_p"].value_counts().sort_index()

# %% [markdown]
# ## Fetched index only for the respective column

# %%
rawDataUpdate["ssc_p"].value_counts().sort_index().index

# %% [markdown]
# ## Fetched value only for the respective column

# %%
rawDataUpdate["ssc_p"].value_counts().sort_index().values

# %%
#rawDataUpdate[quantitative].value_counts().sort_index().index

# %% [markdown]
# ## Created table for Measure of Location of the data

# %%
frequencyRelativeCunmsum_Table = pd.DataFrame(columns = ["Unique_Values", "Frequency", "Relative_Frequency", "Cumulative_Frequency"])

frequencyRelativeCunmsum_Table
# Out:
# Empty DataFrame
# Columns: [Unique_Values, Frequency, Relative_Frequency, Cumulative_Frequency]
# Index: []

# %%
def analysingFrequency(rawDataUpdate, quantitative):
    
    frequencyRelativeCunmsum_Table = pd.DataFrame(columns = ["Unique_Values", "Frequency", "Relative_Frequency", "Cumulative_Frequency"])

    frequencyRelativeCunmsum_Table["Unique_Values"] = rawDataUpdate[quantitative].value_counts().sort_index().index
    frequencyRelativeCunmsum_Table["Frequency"] = rawDataUpdate[quantitative].value_counts().sort_index().values
    frequencyRelativeCunmsum_Table["Relative_Frequency"] = frequencyRelativeCunmsum_Table["Frequency"]/len(frequencyRelativeCunmsum_Table)*100
    frequencyRelativeCunmsum_Table["Cumulative_Frequency"] = frequencyRelativeCunmsum_Table["Relative_Frequency"].cumsum()
    return frequencyRelativeCunmsum_Table

analysingFrequency(rawDataUpdate, "degree_p")
# Out:
#     Unique_Values  Frequency  Relative_Frequency  Cumulative_Frequency
# 0            50.0          1            1.123596              1.123596
# 1            50.2          1            1.123596              2.247191
# 2            50.8          1            1.123596              3.370787
# 3            52.0          3            3.370787              6.741573
# 4            53.0          2            2.247191              8.988764
# ..            ...        ...                 ...                   ...
# 84           82.0          1            1.123596            237.078652
# 85           83.0          1            1.123596            238.202247
# 86           84.0          1            1.123596            239.325843
# 87           85.0          1            1.123596            240.449438
# 88           91.0          1            1.123596            241.573034
#
# [89 rows x 4 columns]

# %%
centralTendencyTable
# Out:
#                           ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean                  67.303395  66.333163  66.370186  72.100558  62.278186
# Median                     67.0       65.0       66.0       71.0       62.0
# Mode                       62.0       63.0       65.0       60.0       56.7
# Percentile(Q1)-25th        60.6       60.9       61.0       60.0     57.945
# Percentile-35th            63.0      62.45      64.18       64.0     59.466
# Percentile(Q2)-50th        67.0       65.0       66.0       71.0       62.0
# Percentile-60th            70.0      67.52      67.44       75.0      63.02
# Percentile(Q3)-75th        75.7       73.0       72.0       83.5     66.255
# Percentile-80th            77.0     74.728     72.134       86.0     67.144
# Percentile-99th            87.0      91.86      83.86       97.0    76.1142
# Percentile(Q4)-100th       89.4       97.7       91.0       98.0      77.89
# ...

# %%
rawDataUpdate

# %%
centralTendencyTable["ssc_p"]["Lesser_Outlier"] > centralTendencyTable["ssc_p"]["Minimum_Value"]

# %%
lesserOutlier = [];

greaterOutlier = [];

for outlierColumn in quantitative:
    
    if(centralTendencyTable[outlierColumn]["Lesser_Outlier"] > centralTendencyTable[outlierColumn]["Minimum_Value"]):
        
        lesserOutlier.append(outlierColumn)
        
    if(centralTendencyTable[outlierColumn]["Greater_Outlier"] < centralTendencyTable[outlierColumn]["Maximum_Value"]):
        
        greaterOutlier.append(outlierColumn)

# %%
lesserOutlier
# Out:
# ['hsc_p']

# %%
greaterOutlier
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
for replaceLesserColumn in lesserOutlier:
    
    rawDataUpdate[replaceLesserColumn][rawDataUpdate[replaceLesserColumn] < centralTendencyTable[replaceLesserColumn]["Lesser_Outlier"]] = centralTendencyTable[replaceLesserColumn]["Lesser_Outlier"]

for replaceGreaterColumn in greaterOutlier:
    
    rawDataUpdate[replaceGreaterColumn][rawDataUpdate[replaceGreaterColumn] > centralTendencyTable[replaceGreaterColumn]["Greater_Outlier"]] = centralTendencyTable[replaceGreaterColumn]["Greater_Outlier"]
# Out:
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
replaced_centralTendency = centralTendency(rawDataUpdate, quantitative);

replaced_centralTendency
# Out:
#                           ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean                  67.303395  66.334744  66.358558  72.100558  62.278186
# Median                     67.0       65.0       66.0       71.0       62.0
# Mode                       62.0       63.0       65.0       60.0       56.7
# Percentile(Q1)-25th        60.6       60.9       61.0       60.0     57.945
# Percentile-35th            63.0      62.45      64.18       64.0     59.466
# Percentile(Q2)-50th        67.0       65.0       66.0       71.0       62.0
# Percentile-60th            70.0      67.52      67.44       75.0      63.02
# Percentile(Q3)-75th        75.7       73.0       72.0       83.5     66.255
# Percentile-80th            77.0     74.728     72.134       86.0     67.144
# Percentile-99th            87.0     91.129      83.86       97.0    76.1142
# Percentile(Q4)-100th       89.4      91.15       88.5       98.0      77.89
# ...

# %%
lesserOulierColumnName = [];

greaterOutlierColumnName = [];

for lesserColumn in quantitative:
    
    if(replaced_centralTendency[lesserColumn]["Lesser_Outlier"] > replaced_centralTendency[lesserColumn]["Minimum_Value"]):
        
        lesserOulierColumnName.append(lesserColumn)
        
    if(replaced_centralTendency[lesserColumn]["Greater_Outlier"] < replaced_centralTendency[lesserColumn]["Maximum_Value"]):
        
        greaterOutlierColumnName.append(lesserColumn)

# %%
lesserOulierColumnName
# Out:
# []

# %%
greaterOutlierColumnName
# Out:
# []

# %%
rawDataUpdate
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
replaced_centralTendency
# Out:
#                           ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean                  67.303395  66.334744  66.358558  72.100558  62.278186
# Median                     67.0       65.0       66.0       71.0       62.0
# Mode                       62.0       63.0       65.0       60.0       56.7
# Percentile(Q1)-25th        60.6       60.9       61.0       60.0     57.945
# Percentile-35th            63.0      62.45      64.18       64.0     59.466
# Percentile(Q2)-50th        67.0       65.0       66.0       71.0       62.0
# Percentile-60th            70.0      67.52      67.44       75.0      63.02
# Percentile(Q3)-75th        75.7       73.0       72.0       83.5     66.255
# Percentile-80th            77.0     74.728     72.134       86.0     67.144
# Percentile-99th            87.0     91.129      83.86       97.0    76.1142
# Percentile(Q4)-100th       89.4      91.15       88.5       98.0      77.89
# ...

# %%
rawDataUpdate.to_csv("PreProcessed_Placement.csv", index = False)

preprocessedPlacement = pd.read_csv("PreProcessed_Placement.csv")

preprocessedPlacement
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
preprocessedPlacement.skew()
# Out:
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# sl_no       0.000000
# ssc_p      -0.132649
# hsc_p       0.162611
# degree_p    0.204164
# etest_p     0.282308
# mba_p       0.313576
# salary      0.125415
# dtype: float64

# %%
preprocessedPlacement.kurtosis()
# Out:
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# sl_no      -1.200000
# ssc_p      -0.607510
# hsc_p       0.086901
# degree_p   -0.097490
# etest_p    -1.088580
# mba_p      -0.470723
# salary      0.025787
# dtype: float64

# %%
import seaborn as sns;

sns.distplot(preprocessedPlacement["ssc_p"])
# Out:
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# ...

# %%
sns.distplot(preprocessedPlacement["hsc_p"])
# Out:
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# ...

# %%
def get_pdf_probablility(preprocessedPlacement, startrange, endrange):
        

    from matplotlib import pyplot;

    from scipy.stats import norm;

    import seaborn as sns;

    ax = sns.distplot(preprocessedPlacement, kde = True, kde_kws = {"color" : "blue"},color = "Green")

    pyplot.axvline(startrange, color = "Red")

    pyplot.axvline(endrange, color = "Red")

    sample = preprocessedPlacement

    #calculate Mean 

    sample_mean = sample.mean()

    #calculate Standard Deviation 

    sample_std = sample.std()

    print("Mean = %.3f, Standard Deviation = %.3f" % (sample_mean, sample_std))

    # define the Normal Distribution

    dist = norm(sample_mean, sample_std)

    #calculate probability
    #sample probabilities for a range of outcomes

    values = [value for value in range(startrange, endrange)]

    probabilities = [dist.pdf(values) for value in values]

    prob = sum(probabilities)

    print("The area between range({}, {}) : {}".format(startrange, endrange, sum(probabilities)))

    return prob

# %%
get_pdf_probablility(preprocessedPlacement["ssc_p"], 30, 60)
# Out:
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Mean = 67.303, Standard Deviation = 10.827
# The area between range(30, 60) : [0.00292347 0.00400169 0.00543105 0.00730836 0.00975103 0.01289962
#  0.01691993 0.02200471 0.02837448 0.03627734 0.04598734 0.05780115
#  0.07203276 0.08900591 0.1090443  0.13245929 0.15953545 0.19051417
#  0.22557588 0.26482157 0.30825447 0.35576294 0.40710585 0.46190141
#  0.51962083 0.57958766 0.64098375 0.70286226 0.76416781 0.82376354]
# ...

# %%
get_pdf_probablility(preprocessedPlacement["ssc_p"], 40, 90)
# Out:
# Mean = 67.303, Standard Deviation = 10.827
# The area between range(40, 90) : [0.07664557 0.09633526 0.12005459 0.14834319 0.18174051 0.22076549
#  0.26589242 0.31752361 0.3759598  0.44136929 0.51375744 0.59293823
#  0.67850975 0.76983569 0.86603472 0.96597944 1.06830626 1.1714371
#  1.27361301 1.37293923 1.46744034 1.55512358 1.63404748 1.70239271
#  1.75853145 1.80109178 1.82901329 1.84159102 1.83850506 1.81983404
#  1.7860518  1.73800743 1.67688979 1.60417863 1.52158509 1.43098497
#  1.33434833 1.23366906 1.13089801 1.02788261 0.92631546 0.82769364
#  0.73328979 0.64413511 0.56101389 0.48446853 0.41481346 0.35215627
#  0.29642397 0.2473925 ]
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
get_pdf_probablility(preprocessedPlacement["ssc_p"], 55, 55)
# Out:
# Mean = 67.303, Standard Deviation = 10.827
# The area between range(55, 55) : 0
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# ...

# %%
get_pdf_probablility(preprocessedPlacement["ssc_p"], 65, 65)
# Out:
# Mean = 67.303, Standard Deviation = 10.827
# The area between range(65, 65) : 0
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# ...

# %%
get_pdf_probablility(preprocessedPlacement["ssc_p"], 65, 65)

# %%
dir(preprocessedPlacement)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %% [markdown]
# # Covariance

# %%
preprocessedPlacement.cov()
# Out:
#                  sl_no          ssc_p          hsc_p       degree_p  \
# sl_no      3870.000000     -52.641355     -59.598879     -41.465047
# ssc_p       -52.641355     117.228377      58.853253      42.702550
# hsc_p       -59.598879      58.853253     112.063731      33.684453
# degree_p    -41.465047      42.702550      33.684453      53.604710
# etest_p      52.556168      37.659225      33.838355      22.078774
# mba_p         8.102336      24.535952      21.517688      17.185200
# salary    11383.177570  908858.485818  731007.850848  466336.264888
#
#                 etest_p          mba_p        salary
# sl_no         52.556168       8.102336  1.138318e+04
# ssc_p         37.659225      24.535952  9.088585e+05
# hsc_p         33.838355      21.517688  7.310079e+05
# degree_p      22.078774      17.185200  4.663363e+05
# etest_p      176.251018      16.886973  3.727004e+05
# mba_p         16.886973      34.028376  1.239934e+05
# ...

# %%
preprocessedPlacement["ssc_p"].cov(preprocessedPlacement["hsc_p"])
# Out:
# 58.853252975440135

# %%
from matplotlib import pyplot;

from scipy.stats import norm;

import seaborn as sns;

sns.distplot(preprocessedPlacement,kde = True,kde_kws = {"color" : "blue"},color = "Green")
# Out:
# C:\Users\hp\Anaconda3\envs\virtualml\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3896\2572329529.py in <module>
#       5 import seaborn as sns;
#       6
# ----> 7 sns.distplot(preprocessedPlacement,kde = True,kde_kws = {"color" : "blue"},color = "Green")
#       8
#
# ~\Anaconda3\envs\virtualml\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2634
# ...
