# %% [markdown]
# # Kowshik P
# ## Univariate Fair File
# ## Assignment submitted on 14-May-2022
#
# ## Concepts :
# ## 1. Measure of Location of the data
# ## 2. Measure of the central Tendency

# %%
import pandas as pd;
import numpy as np;

# %%
rawData = pd.read_csv("Placement.csv");

rawData
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
rawData.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
rawData["salary"] = rawData["salary"].fillna(0)

rawDataUpdate = rawData;

rawDataUpdate
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
from Py_Univariate_Analysis import lead_univariate;

obj = lead_univariate();

quantitative = [];
qualitative = [];

# %% [markdown]
# ## Quantitative and Qualitative columns are segregated

# %%
obj.setquantitativeQualitative(rawDataUpdate, quantitative, qualitative)
# Out:
# (['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %% [markdown]
# ## Mean, Median, Mode and Percentile details

# %%
quantitative, qualitative = obj.setquantitativeQualitative(rawDataUpdate, quantitative, qualitative)

percentileCheck = obj.centralTendency(rawDataUpdate, quantitative)

# %%
percentileCheck
# Out:
#                         ssc_p    hsc_p degree_p  etest_p    mba_p  salary
# Mean                  67.3034  66.3332  66.3702  72.1006  62.2782  198702
# Median                     67       65       66       71       62  240000
# Mode                       62       63       65       60     56.7       0
# Percentile(Q1)-25th      60.6     60.9       61       60   57.945       0
# Percentile-35th            63    62.45    64.18       64   59.466  209400
# Percentile(Q2)-50th        67       65       66       71       62  240000
# Percentile-60th            70    67.52    67.44       75    63.02  250800
# Percentile(Q3)-75th      75.7       73       72     83.5   66.255  282500
# Percentile-80th            77   74.728   72.134       86   67.144  300000
# Percentile-99th            87    91.86    83.86       97  76.1142  629000
# Percentile(Q4)-100th     89.4     97.7       91       98    77.89  940000
# IQR                      15.1     12.1       11     23.5     8.31  282500
# ...

# %% [markdown]
# ## Complete frequencies detail

# %%
Ssc_Frequencies = obj.analysingFrequency(rawDataUpdate, "ssc_p")
Hsc_Frequencies = obj.analysingFrequency(rawDataUpdate, "hsc_p")
Degree_Frequencies = obj.analysingFrequency(rawDataUpdate, "degree_p")
EntranceTest_Frequencies = obj.analysingFrequency(rawDataUpdate, "etest_p")
MBA_Frequencies = obj.analysingFrequency(rawDataUpdate, "mba_p")
Salary_Frequencies = obj.analysingFrequency(rawDataUpdate, "salary")

# %% [markdown]
# ## 10th - Frequency details

# %%
Ssc_Frequencies
# Out:
#      Unique_Values  Frequency  Relative_Frequency  Cumulative_Frequency
# 0            40.89          1            0.970874              0.970874
# 1            41.00          1            0.970874              1.941748
# 2            43.00          1            0.970874              2.912621
# 3            44.00          1            0.970874              3.883495
# 4            45.00          1            0.970874              4.854369
# ..             ...        ...                 ...                   ...
# 98           85.80          1            0.970874            202.912621
# 99           86.50          1            0.970874            203.883495
# 100          87.00          3            2.912621            206.796117
# 101          88.00          1            0.970874            207.766990
# 102          89.40          1            0.970874            208.737864
#
# [103 rows x 4 columns]

# %% [markdown]
# ## 12th - Frequency details

# %%
Hsc_Frequencies
# Out:
#     Unique_Values  Frequency  Relative_Frequency  Cumulative_Frequency
# 0           37.00          1            1.030928              1.030928
# 1           39.00          1            1.030928              2.061856
# 2           40.00          1            1.030928              3.092784
# 3           42.00          1            1.030928              4.123711
# 4           42.16          1            1.030928              5.154639
# ..            ...        ...                 ...                   ...
# 92          90.90          1            1.030928            217.525773
# 93          91.00          1            1.030928            218.556701
# 94          92.00          1            1.030928            219.587629
# 95          97.00          1            1.030928            220.618557
# 96          97.70          1            1.030928            221.649485
#
# [97 rows x 4 columns]

# %% [markdown]
# ## UG Dgree - Frequency details

# %%
Degree_Frequencies
# Out:
#     Unique_Values  Frequency  Relative_Frequency  Cumulative_Frequency
# 0            50.0          1            1.123596              1.123596
# 1            50.2          1            1.123596              2.247191
# 2            50.8          1            1.123596              3.370787
# 3            52.0          3            3.370787              6.741573
# 4            53.0          2            2.247191              8.988764
# ..            ...        ...                 ...                   ...
# 84           82.0          1            1.123596            237.078652
# 85           83.0          1            1.123596            238.202247
# 86           84.0          1            1.123596            239.325843
# 87           85.0          1            1.123596            240.449438
# 88           91.0          1            1.123596            241.573034
#
# [89 rows x 4 columns]

# %% [markdown]
# ## Entrance Test - Frequency details

# %%
EntranceTest_Frequencies
# Out:
#     Unique_Values  Frequency  Relative_Frequency  Cumulative_Frequency
# 0           50.00          3                 3.0                   3.0
# 1           50.48          1                 1.0                   4.0
# 2           50.89          1                 1.0                   5.0
# 3           52.00          1                 1.0                   6.0
# 4           53.04          1                 1.0                   7.0
# ..            ...        ...                 ...                   ...
# 95          96.00          2                 2.0                 210.0
# 96          96.80          1                 1.0                 211.0
# 97          97.00          2                 2.0                 213.0
# 98          97.40          1                 1.0                 214.0
# 99          98.00          1                 1.0                 215.0
#
# [100 rows x 4 columns]

# %% [markdown]
# ## PG MBA- Frequency details

# %%
MBA_Frequencies
# Out:
#      Unique_Values  Frequency  Relative_Frequency  Cumulative_Frequency
# 0            51.21          1            0.487805              0.487805
# 1            51.29          1            0.487805              0.975610
# 2            51.45          1            0.487805              1.463415
# 3            51.58          1            0.487805              1.951220
# 4            52.21          1            0.487805              2.439024
# ..             ...        ...                 ...                   ...
# 200          74.56          1            0.487805            102.926829
# 201          75.71          1            0.487805            103.414634
# 202          76.18          1            0.487805            103.902439
# 203          76.26          1            0.487805            104.390244
# 204          77.89          1            0.487805            104.878049
#
# [205 rows x 4 columns]

# %% [markdown]
# ## Placement salary - Frequency details

# %%
Salary_Frequencies
# Out:
#     Unique_Values  Frequency  Relative_Frequency  Cumulative_Frequency
# 0             0.0         67          145.652174            145.652174
# 1        200000.0          6           13.043478            158.695652
# 2        204000.0          2            4.347826            163.043478
# 3        210000.0          4            8.695652            171.739130
# 4        216000.0          3            6.521739            178.260870
# 5        218000.0          2            4.347826            182.608696
# 6        220000.0          5           10.869565            193.478261
# 7        225000.0          1            2.173913            195.652174
# 8        230000.0          2            4.347826            200.000000
# 9        231000.0          1            2.173913            202.173913
# 10       233000.0          1            2.173913            204.347826
# 11       236000.0          2            4.347826            208.695652
# ...
