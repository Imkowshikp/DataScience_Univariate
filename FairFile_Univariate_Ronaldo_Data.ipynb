# %% [markdown]
# # Kowshik P
#
# ## Data Science
# ## Ronaldo's Data
# ## Fair file for Deployment
# ## -----------------------------------------------------------------------------
# ## Concept - Univariate Data Analysis(Qualitative and Quantitative)
# ## Submitted date on 06-May-2022
# ## -----------------------------------------------------------------------------

# %%
import pandas as pd;

# %%
rawData = pd.read_csv("Ronaldo_Data.csv");

rawData
# Out:
#      Unnamed: 0  Goal_no Season                Competition      Matchday  \
# 0             0        1    2/3              Liga Portugal             6
# 1             1        2    2/3              Liga Portugal             6
# 2             2        3    2/3              Liga Portugal             8
# 3             3        4    2/3  Ta̤a de Portugal Placard  Fourth Round
# 4             4        5    2/3  Ta̤a de Portugal Placard   Fifth Round
# ..          ...      ...    ...                        ...           ...
# 693         693      694  21/22             Premier League            33
# 694         694      695  21/22             Premier League            33
# 695         695      696  21/22             Premier League            34
# 696         696      697  21/22             Premier League            37
# 697         697      698  21/22             Premier League            35
#
#     Venue               Team                 Opponent Result Position Minute  \
# 0       H        Sporting CP            Moreirense FC    3:0       LW     34
# 1       H        Sporting CP            Moreirense FC    3:0      NaN   90+5
# 2       A        Sporting CP              Boavista FC    1:2      NaN     88
# 3       H        Sporting CP             CD Estarreja    4:1      NaN     67
# 4       H        Sporting CP  FC Oliveira do Hospital    8:1      NaN     13
# ..    ...                ...                      ...    ...      ...    ...
# 693     H  Manchester United             Norwich City    3:2       CF     32
# 694     H  Manchester United             Norwich City    3:2       CF     76
# 695     A  Manchester United               Arsenal FC    3:1       CF     34
# 696     H  Manchester United               Chelsea FC    1:1       CF     62
# 697     H  Manchester United             Brentford FC    3:0       CF     61
#
#     At_score       Type_of_goal
# 0        2:0           Solo run
# 1        3:0             Header
# 2        1:2  Right-footed shot
# 3        3:0   Left-footed shot
# 4        3:0                NaN
# ..       ...                ...
# 693      2:0             Header
# 694      3:2   Direct free kick
# 695      2:1   Left-footed shot
# 696      1:1  Right-footed shot
# 697      2:0            Penalty
#
# [698 rows x 13 columns]

# %% [markdown]
# ## Call the class from the respective repository

# %%
from py_univariate import univariateStudentData

# %%
objectClass = univariateStudentData()

# %%
qualitativeData, quantitativeData = objectClass.putQualitativeQuantitative(rawData);
# Out:
# Unnamed: 0
# Goal_no
# Season
# Competition
# Matchday
# Venue
# Team
# Opponent
# Result
# Position
# Minute
# At_score
# Type_of_goal

# %% [markdown]
# ## Qualitative columns

# %%
print(qualitativeData);
# Out:
# ['Season', 'Competition', 'Matchday', 'Venue', 'Team', 'Opponent', 'Result', 'Position', 'Minute', 'At_score', 'Type_of_goal']

# %% [markdown]
# ## Quantitative columns

# %%
print(quantitativeData);
# Out:
# ['Unnamed: 0', 'Goal_no']
